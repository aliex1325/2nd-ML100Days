# %% [markdown]
# ## Work
# 1. 請改變 reduce_lr 的 patience 和 factor 並比較不同設定下，對訓練/驗證集的影響
# 2. 請將 optimizer 換成 Adam、RMSprop 搭配 reduce_lr 並比較訓練結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Sean\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    """Code Here
    建立你的神經網路
    """
    return model

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
#LEARNING_RATE = 1e-3
#EPOCHS = 25 # IF you feel too run to finish, try to make it smaller
#BATCH_SIZE = 1024 

LEARNING_RATE = 1e-3
EPOCHS = 20
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import ReduceLROnPlateau

optimizer_set = [keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=0.95),
                 keras.optimizers.Adam(lr=LEARNING_RATE),
                 keras.optimizers.RMSprop(lr=LEARNING_RATE)]

"""Code Here
建立實驗的比較組合
"""
reduce_lr_factor = [0.001,0.0001]
redice_lr_patient = [5,10]

# %%
import itertools
results = {}
for i, (optim, reduce_factor, reduce_patient) in enumerate(itertools.product(optimizer_set, reduce_lr_factor, redice_lr_patient)):
    print("Numbers of exp: %i, reduce_factor: %.2f, reduce_patient: %i" % (i, reduce_factor, reduce_patient))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optim)
    
    """Code Here
    設定 reduce learning rate 的 callback function
    """
    
    reduce_lr = ReduceLROnPlateau(factor=0.5, 
                              min_lr=reduce_factor, 
                              monitor='val_loss', 
                              patience=reduce_patient, 
                              verbose=1)
    
    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True,
              callbacks=[reduce_lr]
             )

    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# Numbers of exp: 0, reduce_factor: 0.00, reduce_patient: 5
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.2025 - accuracy: 0.2681 - val_loss: 2.1058 - val_accuracy: 0.2347
# Epoch 2/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.7469 - accuracy: 0.3922 - val_loss: 1.9681 - val_accuracy: 0.3127
# Epoch 3/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.6234 - accuracy: 0.4322 - val_loss: 1.8216 - val_accuracy: 0.3791
# Epoch 4/20
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5506 - accuracy: 0.4567 - val_loss: 1.7343 - val_accuracy: 0.3999
# Epoch 5/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.4942 - accuracy: 0.4789 - val_loss: 1.6435 - val_accuracy: 0.4286
# Epoch 6/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.4474 - accuracy: 0.4941 - val_loss: 1.6001 - val_accuracy: 0.4407
# Epoch 7/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.4074 - accuracy: 0.5093 - val_loss: 1.5548 - val_accuracy: 0.4591
# Epoch 8/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.3711 - accuracy: 0.5228 - val_loss: 1.5233 - val_accuracy: 0.4620
# Epoch 9/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.3358 - accuracy: 0.5403 - val_loss: 1.5103 - val_accuracy: 0.4664
# Epoch 10/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.3057 - accuracy: 0.5460 - val_loss: 1.5000 - val_accuracy: 0.4692
# Epoch 11/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.2763 - accuracy: 0.5588 - val_loss: 1.4927 - val_accuracy: 0.4717
# Epoch 12/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.2489 - accuracy: 0.5685 - val_loss: 1.4870 - val_accuracy: 0.4758
# Epoch 13/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2222 - accuracy: 0.5771 - val_loss: 1.4897 - val_accuracy: 0.4769
# Epoch 14/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1957 - accuracy: 0.5900 - val_loss: 1.4656 - val_accuracy: 0.4834
# Epoch 15/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1704 - accuracy: 0.5957 - val_loss: 1.4759 - val_accuracy: 0.4880
# Epoch 16/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1465 - accuracy: 0.6069 - val_loss: 1.4656 - val_accuracy: 0.4896
# Epoch 17/20
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.1230 - accuracy: 0.6144 - val_loss: 1.4629 - val_accuracy: 0.4878
# Epoch 18/20
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.1003 - accuracy: 0.6238 - val_loss: 1.4688 - val_accuracy: 0.4850
# Epoch 19/20
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.0794 - accuracy: 0.6328 - val_loss: 1.4712 - val_accuracy: 0.4880
# Epoch 20/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.0561 - accuracy: 0.6422 - val_loss: 1.4796 - val_accuracy: 0.4883
# Numbers of exp: 1, reduce_factor: 0.00, reduce_patient: 10
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.2381 - accuracy: 0.2640 - val_loss: 2.1001 - val_accuracy: 0.2148
# Epoch 2/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.7534 - accuracy: 0.3899 - val_loss: 1.9638 - val_accuracy: 0.2877
# Epoch 3/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.6293 - accuracy: 0.4318 - val_loss: 1.8392 - val_accuracy: 0.3528
# Epoch 4/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.5549 - accuracy: 0.4583 - val_loss: 1.7357 - val_accuracy: 0.3970
# Epoch 5/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.4998 - accuracy: 0.4763 - val_loss: 1.6462 - val_accuracy: 0.4278
# Epoch 6/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.4550 - accuracy: 0.4915 - val_loss: 1.5988 - val_accuracy: 0.4401
# Epoch 7/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.4147 - accuracy: 0.5079 - val_loss: 1.5619 - val_accuracy: 0.4509
# Epoch 8/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.3798 - accuracy: 0.5200 - val_loss: 1.5391 - val_accuracy: 0.4555
# Epoch 9/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.3476 - accuracy: 0.5313 - val_loss: 1.5133 - val_accuracy: 0.4626
# Epoch 10/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.3155 - accuracy: 0.5422 - val_loss: 1.5013 - val_accuracy: 0.4695
# Epoch 11/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.2884 - accuracy: 0.5536 - val_loss: 1.5033 - val_accuracy: 0.4676
# Epoch 12/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.2592 - accuracy: 0.5641 - val_loss: 1.4826 - val_accuracy: 0.4761
# Epoch 13/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2320 - accuracy: 0.5744 - val_loss: 1.4882 - val_accuracy: 0.4734
# Epoch 14/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.2092 - accuracy: 0.5824 - val_loss: 1.4721 - val_accuracy: 0.4813
# Epoch 15/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1823 - accuracy: 0.5925 - val_loss: 1.4642 - val_accuracy: 0.4837
# Epoch 16/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1578 - accuracy: 0.6018 - val_loss: 1.4660 - val_accuracy: 0.4852
# Epoch 17/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1342 - accuracy: 0.6116 - val_loss: 1.4602 - val_accuracy: 0.4856
# Epoch 18/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1108 - accuracy: 0.6206 - val_loss: 1.4727 - val_accuracy: 0.4815
# Epoch 19/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.0898 - accuracy: 0.6276 - val_loss: 1.4860 - val_accuracy: 0.4866
# Epoch 20/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.0659 - accuracy: 0.6376 - val_loss: 1.4514 - val_accuracy: 0.4908
# Numbers of exp: 2, reduce_factor: 0.00, reduce_patient: 5
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.1791 - accuracy: 0.2653 - val_loss: 2.0812 - val_accuracy: 0.2438
# Epoch 2/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.7508 - accuracy: 0.3906 - val_loss: 1.9443 - val_accuracy: 0.3250
# Epoch 3/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.6312 - accuracy: 0.4269 - val_loss: 1.8133 - val_accuracy: 0.3718
# Epoch 4/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.5575 - accuracy: 0.4541 - val_loss: 1.7177 - val_accuracy: 0.4020
# Epoch 5/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.5020 - accuracy: 0.4751 - val_loss: 1.6361 - val_accuracy: 0.4279
# Epoch 6/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.4570 - accuracy: 0.4919 - val_loss: 1.5860 - val_accuracy: 0.4433
# Epoch 7/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.4174 - accuracy: 0.5043 - val_loss: 1.5544 - val_accuracy: 0.4528
# Epoch 8/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.3818 - accuracy: 0.5192 - val_loss: 1.5211 - val_accuracy: 0.4591
# Epoch 9/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.3510 - accuracy: 0.5289 - val_loss: 1.5040 - val_accuracy: 0.4632
# Epoch 10/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.3214 - accuracy: 0.5381 - val_loss: 1.4996 - val_accuracy: 0.4680
# Epoch 11/20
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.2940 - accuracy: 0.5477 - val_loss: 1.4928 - val_accuracy: 0.4739
# Epoch 12/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2664 - accuracy: 0.5585 - val_loss: 1.4726 - val_accuracy: 0.4782
# Epoch 13/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2409 - accuracy: 0.5678 - val_loss: 1.4739 - val_accuracy: 0.4765
# Epoch 14/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2163 - accuracy: 0.5778 - val_loss: 1.4738 - val_accuracy: 0.4751
# Epoch 15/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.1897 - accuracy: 0.5877 - val_loss: 1.4693 - val_accuracy: 0.4801
# Epoch 16/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.1685 - accuracy: 0.5955 - val_loss: 1.4598 - val_accuracy: 0.4858
# Epoch 17/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.1439 - accuracy: 0.6047 - val_loss: 1.4671 - val_accuracy: 0.4848
# Epoch 18/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.1219 - accuracy: 0.6142 - val_loss: 1.4481 - val_accuracy: 0.4904
# Epoch 19/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.0992 - accuracy: 0.6229 - val_loss: 1.4544 - val_accuracy: 0.4913
# Epoch 20/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.0778 - accuracy: 0.6323 - val_loss: 1.4540 - val_accuracy: 0.4884
# Numbers of exp: 3, reduce_factor: 0.00, reduce_patient: 10
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.2082 - accuracy: 0.2673 - val_loss: 2.1820 - val_accuracy: 0.1653
# Epoch 2/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.7464 - accuracy: 0.3914 - val_loss: 1.9825 - val_accuracy: 0.2758
# Epoch 3/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.6178 - accuracy: 0.4356 - val_loss: 1.8332 - val_accuracy: 0.3536
# Epoch 4/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.5430 - accuracy: 0.4608 - val_loss: 1.7098 - val_accuracy: 0.4138
# Epoch 5/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.4870 - accuracy: 0.4804 - val_loss: 1.6415 - val_accuracy: 0.4277
# Epoch 6/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.4427 - accuracy: 0.4965 - val_loss: 1.5803 - val_accuracy: 0.4491
# Epoch 7/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.4014 - accuracy: 0.5119 - val_loss: 1.5507 - val_accuracy: 0.4574
# Epoch 8/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.3671 - accuracy: 0.5248 - val_loss: 1.5234 - val_accuracy: 0.4659
# Epoch 9/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.3361 - accuracy: 0.5339 - val_loss: 1.5138 - val_accuracy: 0.4693
# Epoch 10/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.3078 - accuracy: 0.5461 - val_loss: 1.4910 - val_accuracy: 0.4781
# Epoch 11/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2765 - accuracy: 0.5564 - val_loss: 1.4901 - val_accuracy: 0.4755
# Epoch 12/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2493 - accuracy: 0.5687 - val_loss: 1.4829 - val_accuracy: 0.4787
# Epoch 13/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2264 - accuracy: 0.5756 - val_loss: 1.4820 - val_accuracy: 0.4770
# Epoch 14/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.2000 - accuracy: 0.5859 - val_loss: 1.4806 - val_accuracy: 0.4814
# Epoch 15/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.1736 - accuracy: 0.5962 - val_loss: 1.4611 - val_accuracy: 0.4880
# Epoch 16/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.1504 - accuracy: 0.6047 - val_loss: 1.4883 - val_accuracy: 0.4786
# Epoch 17/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.1288 - accuracy: 0.6136 - val_loss: 1.4711 - val_accuracy: 0.4857
# Epoch 18/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.1048 - accuracy: 0.6201 - val_loss: 1.4746 - val_accuracy: 0.4863
# Epoch 19/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.0826 - accuracy: 0.6299 - val_loss: 1.4659 - val_accuracy: 0.4862
# Epoch 20/20
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.0604 - accuracy: 0.6391 - val_loss: 1.4675 - val_accuracy: 0.4889
# Numbers of exp: 4, reduce_factor: 0.00, reduce_patient: 5
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.7614 - accuracy: 0.3882 - val_loss: 2.1888 - val_accuracy: 0.2436
# Epoch 2/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.4914 - accuracy: 0.4734 - val_loss: 1.7908 - val_accuracy: 0.3580
# Epoch 3/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.3840 - accuracy: 0.5114 - val_loss: 1.7318 - val_accuracy: 0.3830
# Epoch 4/20
# 50000/50000 [==============================] - 2s 49us/step - loss: 1.3161 - accuracy: 0.5356 - val_loss: 1.8293 - val_accuracy: 0.3689
# Epoch 5/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.2490 - accuracy: 0.5618 - val_loss: 1.7883 - val_accuracy: 0.3832
# Epoch 6/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.1940 - accuracy: 0.5798 - val_loss: 2.1217 - val_accuracy: 0.3241
# Epoch 7/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.1445 - accuracy: 0.5973 - val_loss: 1.8298 - val_accuracy: 0.3767
# Epoch 8/20
# 50000/50000 [==============================] - 2s 49us/step - loss: 1.1016 - accuracy: 0.6124 - val_loss: 1.6114 - val_accuracy: 0.4405
# Epoch 9/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.0536 - accuracy: 0.6295 - val_loss: 1.9840 - val_accuracy: 0.3637
# Epoch 10/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.0096 - accuracy: 0.6439 - val_loss: 1.7716 - val_accuracy: 0.3912
# Epoch 11/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.9821 - accuracy: 0.6548 - val_loss: 1.8400 - val_accuracy: 0.3980
# Epoch 12/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.9372 - accuracy: 0.6714 - val_loss: 1.6654 - val_accuracy: 0.4208
# Epoch 13/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.9038 - accuracy: 0.6826 - val_loss: 2.1807 - val_accuracy: 0.3450
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 14/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.8584 - accuracy: 0.7006 - val_loss: 1.8497 - val_accuracy: 0.4155
# Epoch 15/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.8327 - accuracy: 0.7087 - val_loss: 2.0640 - val_accuracy: 0.3891
# Epoch 16/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.7936 - accuracy: 0.7224 - val_loss: 1.8328 - val_accuracy: 0.4227
# Epoch 17/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.7583 - accuracy: 0.7349 - val_loss: 2.3389 - val_accuracy: 0.3495
# Epoch 18/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.7250 - accuracy: 0.7479 - val_loss: 1.8902 - val_accuracy: 0.4271
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 19/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.6847 - accuracy: 0.7650 - val_loss: 2.3519 - val_accuracy: 0.3745
# Epoch 20/20
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.6494 - accuracy: 0.7748 - val_loss: 2.0975 - val_accuracy: 0.4180
# Numbers of exp: 5, reduce_factor: 0.00, reduce_patient: 10
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
#  1024/50000 [..............................] - ETA: 21s - loss: 2.9983 - accuracy: 0.1074
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-12-9f884b5d93ff> in <module>()
#      22               validation_data=(x_test, y_test),
#      23               shuffle=True,
# ---> 24               callbacks=[reduce_lr]
#      25              )
#      26
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[3072,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node training_6/Adam/gradients/hidden_layer1_6/MatMul_grad/MatMul_1}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
